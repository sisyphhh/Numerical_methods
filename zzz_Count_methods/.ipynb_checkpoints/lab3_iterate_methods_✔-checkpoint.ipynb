# %%
#
A=[[15, 3 , -5 ,-5],[7, -15, -6, 1],[-4, 7, -19, -6],[3, 0, -5, 8]]
B=[36, -112, 19, -23]
X=[]
Tmp=[]
eps=0.01
for i in range(len(A)):
    print(A[i][0:],B[i])

    
#find max delta for future
devi=0    
for i in range(len(A[1])):
    if abs(A[0][i]-A[1][i])>devi:
        devi=abs(A[0][i]-A[1][i])
#print(abs(devi))
      
devvi=[]
for i in range(len(A[1])):
    devvi.append(A[0][i]-A[1][i])
#print(abs(max(devvi,key=abs)))

norma=0
for i in range(len(A[1])):
    res=0
    for j in range(len(A[1])):
        res+=abs(A[i][j])
    if(norma<res):
        norma=res
        
#print(norma)
           
#for i in range(len(A)):
#    for j in range(len(A[i])):
#        print(A[i][j]," ",end='')
#    print()
# Out:
# [15, 3, -5, -5] 36
# [7, -15, -6, 1] -112
# [-4, 7, -19, -6] 19
# [3, 0, -5, 8] -23

# %%
#method of simple iterations
#check max diagonal el-ts

Tmp.clear()
X.clear()

delta=10000
stop=0
devvi=[]

for j in range(len(A[1])):
    Tmp.append(0)
    X.append(0)

while delta >= eps:
    devvi.clear()
    stop+=1
    if stop==100:
        break
        
    for i in range(len(A[1])):
        box=0
        box+=B[i]
        ##X[i]+=B[i]
        for j in range(len(A[1])):           
            if j==i:
                continue
            box+=(-Tmp[j])*A[i][j]
            ##X[i]+=(-Tmp[j])*A[i][j]

        X[i]=box/A[i][i]
        ##X[i]=X[i]/A[i][i]
        #print(X)
    
    for i in range(len(A[1])):
        devvi.append(X[i]-Tmp[i])
    delta=round(abs(max(devvi,key=abs)),6)
    #print('max difference: ',delta)
    
    for i in range(len(A[1])):
        Tmp[i]=X[i]
        
#print('last delta=',delta,' while epsilon is: ',eps)
print('Answ by simple iterations: ',X,stop)
# Out:
# Answ by simple iterations:  [0.9966361880559848, 7.006168801891861, 1.999668471239438, -2.0074660216269833] 29

# %%
#method of simple iterations by difference between xi & bi
#check max diagonal el-ts

Tmp.clear()
X.clear()

delta=10000
stop=0
devvi=[]

for j in range(len(A[1])):
    Tmp.append(0)
    X.append(0)

while delta >= eps:
    devvi.clear()
    stop+=1
    if stop==100:
        break
        
    for i in range(len(A[1])):
        box=0
        box+=B[i]
        ##X[i]+=B[i]
        for j in range(len(A[1])):           
            if j==i:
                continue
            box+=(-Tmp[j])*A[i][j]
            ##X[i]+=(-Tmp[j])*A[i][j]

        X[i]=box/A[i][i]
        ##X[i]=X[i]/A[i][i]
        print('X:',X)
        print('B',B)
    
    for i in range(len(A[1])):
        box=0
        for j in range(len(A[1])):
            box+=A[i][j]*X[j]
        devvi.append(box-B[i])
    print(devvi)
    delta=round(abs(max(devvi,key=abs)),6)
    #print(B)
    #print('max difference: ',delta)
    
    for i in range(len(A[1])):
        Tmp[i]=X[i]
        
#print('last delta=',delta,' while epsilon is: ',eps)
print('Answ by simple iterations with check by Ax-B: ',X,stop)
# Out:
# X: [2.4, 0, 0, 0]
# B [36, -112, 19, -23]
# X: [2.4, 7.466666666666667, 0, 0]
# B [36, -112, 19, -23]
# X: [2.4, 7.466666666666667, -1.0, 0]
# B [36, -112, 19, -23]
# X: [2.4, 7.466666666666667, -1.0, -2.875]
# B [36, -112, 19, -23]
# [41.775000000000006, 19.924999999999997, 59.91666666666666, 12.2]
# X: [-0.3849999999999999, 7.466666666666667, -1.0, -2.875]
# B [36, -112, 19, -23]
# X: [-0.3849999999999999, 8.795, -1.0, -2.875]
# B [36, -112, 19, -23]
# X: [-0.3849999999999999, 8.795, 2.1535087719298245, -2.875]
# B [36, -112, 19, -23]
# X: [-0.3849999999999999, 8.795, 2.1535087719298245, -4.4]
# B [36, -112, 19, -23]
# [-4.157543859649124, -39.94105263157897, 29.58833333333334, -24.122543859649127]
# X: [-0.10783040935672498, 8.795, 2.1535087719298245, -4.4]
# B [36, -112, 19, -23]
# X: [-0.10783040935672498, 6.132263157894737, 2.1535087719298245, -4.4]
# B [36, -112, 19, -23]
# X: [-0.10783040935672498, 6.132263157894737, 3.71078947368421, -4.4]
# B [36, -112, 19, -23]
# X: [-0.10783040935672498, 6.132263157894737, 3.71078947368421, -1.3846820175438594]
# B [36, -112, 19, -23]
# [-30.851203947368415, -4.38817909356726, -37.839744152046784, -6.9548947368421]
# X: [1.9489165204678363, 6.132263157894737, 3.71078947368421, -1.3846820175438594]
# B [36, -112, 19, -23]
# X: [1.9489165204678363, 5.839717884990254, 3.71078947368421, -1.3846820175438594]
# B [36, -112, 19, -23]
# X: [1.9489165204678363, 5.839717884990254, 1.7192239919975378, -1.3846820175438594]
# B [36, -112, 19, -23]
# X: [1.9489165204678363, 5.839717884990254, 1.7192239919975378, -0.515320175438597]
# B [36, -112, 19, -23]
# [4.7333823791936, 27.215983240997218, -15.490975682261203, 16.128068197907044]
# X: [1.633357695188263, 5.839717884990254, 1.7192239919975378, -0.515320175438597]
# B [36, -112, 19, -23]
# X: [1.633357695188263, 7.654116767723402, 1.7192239919975378, -0.515320175438597]
# B [36, -112, 19, -23]
# X: [1.633357695188263, 7.654116767723402, 0.903909482404843, -0.515320175438597]
# B [36, -112, 19, -23]
# X: [1.633357695188263, 7.654116767723402, 0.903909482404843, -2.5313287001769775]
# B [36, -112, 19, -23]
# [19.59981181985482, 0.6669667558607841, 26.05907862868061, 3.1298960721247546]
# X: [0.3267035738646078, 7.654116767723402, 0.903909482404843, -2.5313287001769775]
# B [36, -112, 19, -23]
# X: [0.3267035738646078, 7.69858121811412, 0.903909482404843, -2.5313287001769775]
# B [36, -112, 19, -23]
# X: [0.3267035738646078, 7.69858121811412, 2.275439936545928, -2.5313287001769775]
# B [36, -112, 19, -23]
# X: [0.3267035738646078, 7.69858121811412, 2.275439936545928, -2.922565709192572]
# B [36, -112, 19, -23]
# [-4.7680738744553, -17.7669985831277, 7.885289692123216, -10.77761463467639]
# X: [0.6445751654949613, 7.69858121811412, 2.275439936545928, -2.922565709192572]
# B [36, -112, 19, -23]
# X: [0.6445751654949613, 6.514114645905608, 2.275439936545928, -2.922565709192572]
# B [36, -112, 19, -23]
# X: [0.6445751654949613, 6.514114645905608, 2.690455183499781, -2.922565709192572]
# B [36, -112, 19, -23]
# X: [0.6445751654949613, 6.514114645905608, 2.690455183499781, -1.5753638798580232]
# B [36, -112, 19, -23]
# [-12.364485098067544, 1.082211489023905, -17.645963347988292, -1.121461459878205]
# X: [1.4688741720327976, 6.514114645905608, 2.690455183499781, -1.5753638798580232]
# B [36, -112, 19, -23]
# X: [1.4688741720327976, 6.586262078507202, 2.690455183499781, -1.5753638798580232]
# B [36, -112, 19, -23]
# X: [1.4688741720327976, 6.586262078507202, 1.761720270447766, -1.5753638798580232]
# B [36, -112, 19, -23]
# X: [1.4688741720327976, 6.586262078507202, 1.761720270447766, -1.4351811973732471]
# B [36, -112, 19, -23]
# [4.159203450640973, 11.482685206561712, -3.6332600928488468, 7.116571584873586]
# X: [1.1915939419900663, 6.586262078507202, 1.761720270447766, -1.4351811973732471]
# B [36, -112, 19, -23]
# X: [1.1915939419900663, 7.351774425611316, 1.761720270447766, -1.4351811973732471]
# B [36, -112, 19, -23]
# X: [1.1915939419900663, 7.351774425611316, 1.5704960550346687, -1.4351811973732471]
# B [36, -112, 19, -23]
# X: [1.1915939419900663, 7.351774425611316, 1.5704960550346687, -2.3247526454824454]
# B [36, -112, 19, -23]
# [7.700515358923823, -1.6831877659297447, 11.805136038554913, 0.12428038693729349]
# X: [0.6782262513951447, 7.351774425611316, 1.5704960550346687, -2.3247526454824454]
# B [36, -112, 19, -23]
# X: [0.6782262513951447, 7.239561907882666, 1.5704960550346687, -2.3247526454824454]
# B [36, -112, 19, -23]
# X: [0.6782262513951447, 7.239561907882666, 2.1918190044322956, -2.3247526454824454]
# B [36, -112, 19, -23]
# X: [0.6782262513951447, 7.239561907882666, 2.1918190044322956, -2.340287693849607]
# B [36, -112, 19, -23]
# [-3.3655770583382747, -7.337046578917352, 1.3611934284821103, -4.646717818772899]
# X: [0.902598055284363, 7.239561907882666, 2.1918190044322956, -2.340287693849607]
# B [36, -112, 19, -23]
# X: [0.902598055284363, 6.750425469288175, 2.1918190044322956, -2.340287693849607]
# B [36, -112, 19, -23]
# X: [0.902598055284363, 6.750425469288175, 2.2634607638260906, -2.340287693849607]
# B [36, -112, 19, -23]
# X: [0.902598055284363, 6.750425469288175, 2.2634607638260906, -1.7594479665029947]
# B [36, -112, 19, -23]
# [-4.729816749485501, 1.7215917982083795, -7.8064806497979795, 0.3149066146986783]
# X: [1.2179191719167302, 6.750425469288175, 2.2634607638260906, -1.7594479665029947]
# B [36, -112, 19, -23]
# X: [1.2179191719167302, 6.8651982558354, 2.2634607638260906, -1.7594479665029947]
# B [36, -112, 19, -23]
# X: [1.2179191719167302, 6.8651982558354, 1.8525933612051442, -1.7594479665029947]
# B [36, -112, 19, -23]
# X: [1.2179191719167302, 6.8651982558354, 1.8525933612051442, -1.7988112933403293]
# B [36, -112, 19, -23]
# [2.595472006933079, 4.633088905314892, -0.22169499967488449, 3.000300363001834]
# X: [1.0448877047878584, 6.8651982558354, 1.8525933612051442, -1.7988112933403293]
# B [36, -112, 19, -23]
# X: [1.0448877047878584, 7.17407084952306, 1.8525933612051442, -1.7988112933403293]
# B [36, -112, 19, -23]
# X: [1.0448877047878584, 7.17407084952306, 1.840925203327519, -1.7988112933403293]
# B [36, -112, 19, -23]
# X: [1.0448877047878584, 7.17407084952306, 1.840925203327519, -2.173848838715559]
# B [36, -112, 19, -23]
# [2.8601462973272476, -1.5162488680115729, 5.104459296580483, -0.4607536119984914]
# X: [0.8542112849660416, 7.17407084952306, 1.840925203327519, -2.173848838715559]
# B [36, -112, 19, -23]
# X: [0.8542112849660416, 7.072987591655622, 1.840925203327519, -2.173848838715559]
# B [36, -112, 19, -23]
# X: [0.8542112849660416, 7.072987591655622, 2.109580955779123, -2.173848838715559]
# B [36, -112, 19, -23]
# X: [0.8542112849660416, 7.072987591655622, 2.109580955779123, -2.1162546372157474]
# B [36, -112, 19, -23]
# [-1.9344995433593937, -2.889075251962524, -0.29044233478366266, -1.9153080217234688]
# X: [0.983177921190001, 7.072987591655622, 2.109580955779123, -2.1162546372157474]
# B [36, -112, 19, -23]
# X: [0.983177921190001, 6.88038257485812, 2.109580955779123, -2.1162546372157474]
# B [36, -112, 19, -23]
# X: [0.983177921190001, 6.88038257485812, 2.0942945171062988, -2.1162546372157474]
# B [36, -112, 19, -23]
# X: [0.983177921190001, 6.88038257485812, 2.0942945171062988, -1.8768411345003135]
# B [36, -112, 19, -23]
# [-1.6984503706055492, 1.233898588320102, -3.3005826787709527, 0.4633321020359986]
# X: [1.096407945897038, 6.88038257485812, 2.0942945171062988, -1.8768411345003135]
# B [36, -112, 19, -23]
# X: [1.096407945897038, 6.962642480746127, 2.0942945171062988, -1.8768411345003135]
# B [36, -112, 19, -23]
# X: [1.096407945897038, 6.962642480746127, 1.9205796392762484, -1.8768411345003135]
# B [36, -112, 19, -23]
# X: [1.096407945897038, 6.962642480746127, 1.9205796392762484, -1.9347576472548136]
# B [36, -112, 19, -23]
# [1.4049366705867783, 1.7769829271750552, 0.4703983189149028, 1.2082644632713624]
# X: [1.002745501191253, 6.962642480746127, 1.9205796392762484, -1.9347576472548136]
# B [36, -112, 19, -23]
# X: [1.002745501191253, 7.081108009224464, 1.9205796392762484, -1.9347576472548136]
# B [36, -112, 19, -23]
# X: [1.002745501191253, 7.081108009224464, 1.9453374455349275, -1.9347576472548136]
# B [36, -112, 19, -23]
# X: [1.002745501191253, 7.081108009224464, 1.9453374455349275, -2.085790705163734]
# B [36, -112, 19, -23]
# [0.986772843686218, -0.9552170084014904, 2.1101068256250173, -0.40477636541075057]
# X: [0.9369606449455051, 7.081108009224464, 1.9453374455349275, -2.085790705163734]
# B [36, -112, 19, -23]
# X: [0.9369606449455051, 7.017426875331031, 1.9453374455349275, -2.085790705163734]
# B [36, -112, 19, -23]
# X: [0.9369606449455051, 7.017426875331031, 2.0563956995151913, -2.085790705163734]
# B [36, -112, 19, -23]
# X: [0.9369606449455051, 7.017426875331031, 2.0563956995151913, -2.03519365948739]
# B [36, -112, 19, -23]
# [-0.9993198999633321, -1.0762464719254865, -0.4862107863290994, -0.7526458386385606]
# X: [1.0035819716097276, 7.017426875331031, 2.0563956995151913, -2.03519365948739]
# B [36, -112, 19, -23]
# X: [1.0035819716097276, 6.945677110536, 2.0563956995151913, -2.03519365948739]
# B [36, -112, 19, -23]
# X: [1.0035819716097276, 6.945677110536, 2.030805658129449, -2.03519365948739]
# B [36, -112, 19, -23]
# X: [1.0035819716097276, 6.945677110536, 2.030805658129449, -1.94111292965757]
# B [36, -112, 19, -23]
# [-0.5577027366054779, 0.7139702647938293, -1.3332180392010287, 0.32781418692137976]
# X: [1.0407621540500929, 6.945677110536, 2.030805658129449, -1.94111292965757]
# B [36, -112, 19, -23]
# X: [1.0407621540500929, 6.993275128188922, 2.030805658129449, -1.94111292965757]
# B [36, -112, 19, -23]
# X: [1.0407621540500929, 6.993275128188922, 1.960636287645185, -1.94111292965757]
# B [36, -112, 19, -23]
# X: [1.0407621540500929, 6.993275128188922, 1.960636287645185, -1.9820897030227422]
# B [36, -112, 19, -23]
# [0.6985247722059427, 0.6403007266229821, 0.430326034000025, 0.46238739974241483]
# X: [0.99419383590303, 6.993275128188922, 1.960636287645185, -1.9820897030227422]
# B [36, -112, 19, -23]
# X: [0.99419383590303, 7.0359618432971205, 1.960636287645185, -1.9820897030227422]
# B [36, -112, 19, -23]
# X: [0.99419383590303, 7.0359618432971205, 1.9832850262767652, -1.9820897030227422]
# B [36, -112, 19, -23]
# X: [0.99419383590303, 7.0359618432971205, 1.9832850262767652, -2.039888127990544]
# B [36, -112, 19, -23]
# [0.30380857700571084, -0.5196690837867379, 0.8318708281524465, -0.25294864759908364]
# X: [0.9739399307693162, 7.0359618432971205, 1.9832850262767652, -2.039888127990544]
# B [36, -112, 19, -23]
# X: [0.9739399307693162, 7.001317237711339, 1.9832850262767652, -2.039888127990544]
# B [36, -112, 19, -23]
# X: [0.9739399307693162, 7.001317237711339, 2.0270677014426837, -2.039888127990544]
# B [36, -112, 19, -23]
# X: [0.9739399307693162, 7.001317237711339, 2.0270677014426837, -2.008269547040658]
# B [36, -112, 19, -23]
# [-0.4809400973363722, -0.3728548059816177, -0.35120810426493776, -0.279675091230736]
# X: [1.0060026039250742, 7.001317237711339, 2.0270677014426837, -2.008269547040658]
# B [36, -112, 19, -23]
# X: [1.0060026039250742, 6.976460250645898, 2.0270677014426837, -2.008269547040658]
# B [36, -112, 19, -23]
# X: [1.0060026039250742, 6.976460250645898, 2.008583064376108, -2.008269547040658]
# B [36, -112, 19, -23]
# X: [1.0060026039250742, 6.976460250645898, 2.008583064376108, -1.9733101606368164]
# B [36, -112, 19, -23]
# [-0.15694470788264425, 0.3703059208935855, -0.5120059205041585, 0.1886112048001536]
# X: [1.0164655844505843, 6.976460250645898, 2.008583064376108, -1.9733101606368164]
# B [36, -112, 19, -23]
# X: [1.0164655844505843, 7.001147312038805, 2.008583064376108, -1.9733101606368164]
# B [36, -112, 19, -23]
# X: [1.0164655844505843, 7.001147312038805, 1.9816353843495729, -1.9733101606368164]
# B [36, -112, 19, -23]
# X: [1.0164655844505843, 7.001147312038805, 1.9816353843495729, -1.9968865612368356]
# B [36, -112, 19, -23]
# [0.3266815873114979, 0.21135054323774227, 0.2724159112484301, 0.16612734170920262]
# X: [0.9946868119631515, 7.001147312038805, 1.9816353843495729, -1.9968865612368356]
# B [36, -112, 19, -23]
# X: [0.9946868119631515, 7.015237348254654, 1.9816353843495729, -1.9968865612368356]
# B [36, -112, 19, -23]
# X: [0.9946868119631515, 7.015237348254654, 1.995973063888964, -1.9968865612368356]
# B [36, -112, 19, -23]
# X: [0.9946868119631515, 7.015237348254654, 1.995973063888964, -2.0176524789504864]
# B [36, -112, 19, -23]
# [0.07441129951885017, -0.25924340236201715, 0.3103408497425768, -0.13702471515925652]
# X: [0.9897260586618949, 7.015237348254654, 1.995973063888964, -2.0176524789504864]
# B [36, -112, 19, -23]
# X: [0.9897260586618949, 6.997954454763853, 1.995973063888964, -2.0176524789504864]
# B [36, -112, 19, -23]
# X: [0.9897260586618949, 6.997954454763853, 2.0123067928227836, -2.0176524789504864]
# B [36, -112, 19, -23]
# X: [0.9897260586618949, 6.997954454763853, 2.0123067928227836, -2.0005243895555793]
# B [36, -112, 19, -23]
# [-0.21915777211604137, -0.1155995573168127, -0.2039057776000206, -0.09655090457286875]
# X: [1.004336576802964, 6.997954454763853, 2.0123067928227836, -2.0005243895555793]
# B [36, -112, 19, -23]
# X: [1.004336576802964, 6.990247817609399, 2.0123067928227836, -2.0005243895555793]
# B [36, -112, 19, -23]
# X: [1.004336576802964, 6.990247817609399, 2.0015749097912034, -2.0005243895555793]
# B [36, -112, 19, -23]
# X: [1.004336576802964, 6.990247817609399, 2.0015749097912034, -1.988455526483971]
# B [36, -112, 19, -23]
# [-0.029804811663510122, 0.17873378824857866, -0.18480171107510301, 0.0974909695811057]
# X: [1.006323564247198, 6.990247817609399, 2.0015749097912034, -1.988455526483971]
# B [36, -112, 19, -23]
# X: [1.006323564247198, 7.002163403492637, 2.0015749097912034, -1.988455526483971]
# B [36, -112, 19, -23]
# X: [1.006323564247198, 7.002163403492637, 1.9918485039451452, -1.988455526483971]
# B [36, -112, 19, -23]
# X: [1.006323564247198, 7.002163403492637, 1.9918485039451452, -2.0006418976816094]
# B [36, -112, 19, -23]
# [0.14531064286819628, 0.060080975988356045, 0.14857937859156323, 0.054592991562991244]
# X: [0.9966361880559848, 7.002163403492637, 1.9918485039451452, -2.0006418976816094]
# B [36, -112, 19, -23]
# X: [0.9966361880559848, 7.006168801891861, 1.9918485039451452, -2.0006418976816094]
# B [36, -112, 19, -23]
# X: [0.9966361880559848, 7.006168801891861, 1.999668471239438, -2.0006418976816094]
# B [36, -112, 19, -23]
# X: [0.9966361880559848, 7.006168801891861, 1.999668471239438, -2.0074660216269833]
# B [36, -112, 19, -23]
# [0.007036978453079712, -0.12155556104963239, 0.10773203723166347, -0.06816196504509975]
# X: [0.9961670561591125, 7.006168801891861, 1.999668471239438, -2.0074660216269833]
# B [36, -112, 19, -23]
# X: [0.9961670561591125, 6.998065097821885, 1.999668471239438, -2.0074660216269833]
# B [36, -112, 19, -23]
# X: [0.9961670561591125, 6.998065097821885, 2.0053385784621574, -2.0074660216269833]
# B [36, -112, 19, -23]
# X: [0.9961670561591125, 6.998065097821885, 2.0053385784621574, -1.9989457759963456]
# B [36, -112, 19, -23]
# [-0.09526287647670983, -0.028784320983788803, -0.10597087468617161, -0.029757931804216042]
# X: [1.0025179145908936, 6.998065097821885, 2.0053385784621574, -1.9989457759963456]
# B [36, -112, 19, -23]
# X: [1.0025179145908936, 6.996146143089633, 2.0053385784621574, -1.9989457759963456]
# B [36, -112, 19, -23]
# X: [1.0025179145908936, 6.996146143089633, 1.9997611640049906, -1.9989457759963456]
# B [36, -112, 19, -23]
# X: [1.0025179145908936, 6.996146143089633, 1.9997611640049906, -1.9952260345208188]
# B [36, -112, 19, -23]
# [0.0035315007114391506, 0.08164023724100389, -0.06115456570604749, 0.0469396475811763]
# X: [1.0022824812101305, 6.996146143089633, 1.9997611640049906, -1.9952260345208188]
# B [36, -112, 19, -23]
# X: [1.0022824812101305, 7.001588825572367, 1.9997611640049906, -1.9952260345208188]
# B [36, -112, 19, -23]
# X: [1.0022824812101305, 7.001588825572367, 1.9965425026520403, -1.9952260345208188]
# B [36, -112, 19, -23]
# X: [1.0022824812101305, 7.001588825572367, 1.9965425026520403, -2.001093490468466]
# B [36, -112, 19, -23]
# [0.06175863395118597, 0.011796478504706442, 0.0742452465880703, 0.015387006622461286]
# X: [0.9981652389467182, 7.001588825572367, 1.9965425026520403, -2.001093490468466]
# B [36, -112, 19, -23]
# X: [0.9981652389467182, 7.00237525747268, 1.9965425026520403, -2.001093490468466]
# B [36, -112, 19, -23]
# X: [0.9981652389467182, 7.00237525747268, 2.0004501472093073, -2.001093490468466]
# B [36, -112, 19, -23]
# X: [0.9981652389467182, 7.00237525747268, 2.0004501472093073, -2.0030168662962735]
# B [36, -112, 19, -23]
# [-0.007562047946350958, -0.054189939015302, 0.03351424732269237, -0.031889949576569876]
# X: [0.9986693754764748, 7.00237525747268, 2.0004501472093073, -2.0030168662962735]
# B [36, -112, 19, -23]
# X: [0.9986693754764748, 6.9987625948716605, 2.0004501472093073, -2.0030168662962735]
# B [36, -112, 19, -23]
# X: [0.9986693754764748, 6.9987625948716605, 2.002214054963133, -2.0030168662962735]
# B [36, -112, 19, -23]
# X: [0.9986693754764748, 6.9987625948716605, 2.002214054963133, -1.9990306225992025]
# B [36, -112, 19, -23]
# [-0.03958874505755006, -0.0030682471175822457, -0.05122264650859165, -0.007307129179860539]
# X: [1.001308625146978, 6.9987625948716605, 2.002214054963133, -1.9990306225992025]
# B [36, -112, 19, -23]
# X: [1.001308625146978, 6.998558045063821, 2.002214054963133, -1.9990306225992025]
# B [36, -112, 19, -23]
# X: [1.001308625146978, 6.998558045063821, 1.999518126199523, -1.9990306225992025]
# B [36, -112, 19, -23]
# X: [1.001308625146978, 6.998558045063821, 1.999518126199523, -1.9981172314517197]
# B [36, -112, 19, -23]
# [0.008299038657121116, 0.03556371142266812, -0.017469194221781947, 0.02139739282956299]
# X: [1.00075535590317, 6.998558045063821, 1.999518126199523, -1.9981172314517197]
# B [36, -112, 19, -23]
# X: [1.00075535590317, 7.000928959158666, 1.999518126199523, -1.9981172314517197]
# B [36, -112, 19, -23]
# X: [1.00075535590317, 7.000928959158666, 1.9985986949246923, -1.9981172314517197]
# B [36, -112, 19, -23]
# X: [1.00075535590317, 7.000928959158666, 1.9985986949246923, -2.000791905555415]
# B [36, -112, 19, -23]
# [0.0250832691771663, -0.0010309711613700756, 0.034857520261322605, 0.0029373486427282103]
# X: [0.9990831379580258, 7.000928959158666, 1.9985986949246923, -2.000791905555415]
# B [36, -112, 19, -23]
# X: [0.9990831379580258, 7.000860227747908, 1.9985986949246923, -2.000791905555415]
# B [36, -112, 19, -23]
# X: [0.9990831379580258, 7.000860227747908, 2.0004333012542355, -2.000791905555415]
# B [36, -112, 19, -23]
# X: [0.9990831379580258, 7.000860227747908, 2.0004333012542355, -2.001159074135756]
# B [36, -112, 19, -23]
# [-0.00754338297828383, -0.023080332173606166, 0.008410763387313835, -0.014189685483149361]
# X: [0.9995860301565781, 7.000860227747908, 2.0004333012542355, -2.001159074135756]
# B [36, -112, 19, -23]
# X: [0.9995860301565781, 6.999321538936334, 2.0004333012542355, -2.001159074135756]
# B [36, -112, 19, -23]
# X: [0.9995860301565781, 6.999321538936334, 2.0008759730114627, -2.001159074135756]
# B [36, -112, 19, -23]
# X: [0.9995860301565781, 6.999321538936334, 2.0008759730114627, -1.9993853634503624]
# B [36, -112, 19, -23]
# [-0.015697978647835953, 0.0026379255319000094, -0.023424654587593352, -0.0007046821904772571]
# X: [1.0006325620664334, 6.999321538936334, 2.0008759730114627, -1.9993853634503624]
# B [36, -112, 19, -23]
# X: [1.0006325620664334, 6.999497400638461, 2.0008759730114627, -1.9993853634503624]
# B [36, -112, 19, -23]
# X: [1.0006325620664334, 6.999497400638461, 1.999643096454221, -1.9993853634503624]
# B [36, -112, 19, -23]
# X: [1.0006325620664334, 6.999497400638461, 1.999643096454221, -1.9992972781765528]
# B [36, -112, 19, -23]
# [0.006251541523539572, 0.014811067986229887, -0.0034836073673893964, 0.009303978515774247]
# X: [1.0002157926315307, 6.999497400638461, 1.999643096454221, -1.9992972781765528]
# B [36, -112, 19, -23]
# X: [1.0002157926315307, 7.000484805170876, 1.999643096454221, -1.9992972781765528]
# B [36, -112, 19, -23]
# X: [1.0002157926315307, 7.000484805170876, 1.9994597486980423, -1.9992972781765528]
# B [36, -112, 19, -23]
# X: [1.0002157926315307, 7.000484805170876, 1.9994597486980423, -2.000460275491024]
# B [36, -112, 19, -23]
# [0.009693938950491088, -0.002980296821704087, 0.015556893353345203, -0.00033356952381424776]
# X: [0.9995695300348311, 7.000484805170876, 1.9994597486980423, -2.000460275491024]
# B [36, -112, 19, -23]
# X: [0.9995695300348311, 7.000286118716096, 1.9994597486980423, -2.000460275491024]
# B [36, -112, 19, -23]
# X: [0.9995695300348311, 7.000286118716096, 2.000278532558745, -2.000460275491024]
# B [36, -112, 19, -23]
# X: [0.9995695300348311, 7.000286118716096, 2.000278532558745, -2.0004185793005473]
# B [36, -112, 19, -23]
# [-0.00489845962023594, -0.00939484515063782, 0.0009440680604733132, -0.006032707093609702]
# Answ by simple iterations:  [0.9995695300348311, 7.000286118716096, 2.000278532558745, -2.0004185793005473] 41

# %%
#Ziedel`s method

Tmp.clear()
X.clear()

delta=10000
stop=0
devvi=[]

for j in range(len(A[1])):
    Tmp.append(0)
    X.append(0)

while delta > eps:
    devvi.clear()
    stop+=1
    if stop==50:
        break
        
    for i in range(len(A[1])):
        box=0
        ##X[i]+=B[i]
        box+=B[i]#почему, если работаешь через массив Х-ов, точность падает?
        for j in range(len(A[1])):           
            if j==i:
                continue
            box+=(-X[j])*A[i][j]
            ##X[i]+=(-X[j])*A[i][j] 

        X[i]=box/A[i][i]
        ##X[i]=X[i]/A[i][i]
        ##print(X[i])
        
    for i in range(len(A[1])):
        devvi.append(X[i]-Tmp[i])
    delta=round(abs(max(devvi,key=abs)),6)
    #print('max difference: ',delta)
    
    for i in range(len(A[1])):
        Tmp[i]=X[i]
        
#print('last delta=',delta,' while epsilon is: ',eps)
print('Answ by Ziedel`s method: ',X,stop)
# Out:
# Answ by Ziedel`s method:  [0.9974786112460764, 6.999947150075919, 2.0017814642880714, -1.9979410640372337]

# %%
#Ziedel`s method

Tmp.clear()
X.clear()

delta=10000
stop=0
devvi=[]
NNNorma=1

for j in range(len(A[1])):
    Tmp.append(0)
    X.append(0)

while (abs(NNNorma))**0.5 > eps:
    NNNorma=0
    stop+=1
    if stop==50:
        break
        
    for i in range(len(A[1])):
        box=0
        box+=B[i]
        for j in range(i):           
            box+=(-X[j])*A[i][j]
        for j in range(i+1,len(A[1])):     
            box+=(-Tmp[j])*A[i][j]
        #X[i]+=B[i]
        #print(X[i])
        X[i]=box/A[i][i]
        
    #print(X)
    for i in range(len(A[1])):
        NNNorma+=(X[i]-Tmp[i])*(X[i]-Tmp[i])
    #NNNorma=round(abs(max(devvi,key=abs)),6)
    #print('max difference: ',delta)
    
    for i in range(len(A[1])):
        Tmp[i]=X[i]
        
#print('last delta=',NNNorma,' while epsilon is: ',eps)
#print(X)
