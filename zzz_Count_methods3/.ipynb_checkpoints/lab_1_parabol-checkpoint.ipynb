# %%
import numpy as np
import math 
N = 20 
h = (math.pi/2)/(N)
K = 800
T = 1
tau =(T)/K
print(h)
if tau <= 0.5*(h*h):
    print(tau,'<=',0.5*(h*h),'Well, that`s oke')
else: 
    print('1/2 * h^2 < tau')
    print(tau,0.5*(h*h))

def funk_1(x,t):
    return math.cos(x) * (math.cos(t) + math.sin(t))

sigma=tau/(h*h)

'''
U_xt=np.zeros((N,K))
for j in range (N):
    for k in range(K): 
        if j==0:
            U_xt[j][k]=math.sin(k*tau)
        else:
            if k==0:
                U_xt[j][k]=0     
            elif j==N-1:
                U_xt[j][k]=U_xt[j-1][k] - h*math.sin(k*tau)
            else:
                U_xt[j][k]=sigma*(U_xt[j+1][k-1])+(1-2*sigma)*U_xt[j][k-1] + sigma*U_xt[j-1][k-1] +tau*funk_1(j*h,k*tau)

U_xt=np.array(U_xt).copy() 
U_xt=U_xt.transpose()
#'''
#'''
U_xt=np.zeros((K,N))
for k in range(K):
    #temp_list=[]
    for j in range(N): 
        if j==0:
            U_xt[k][j]=math.sin((k)*tau)
        else:
            if k==0:
                U_xt[k][j]=0
                #temp_list.append(U_xt[k][j])
            elif j==N-1:
                U_xt[k][j]=U_xt[k][j-1] - h*math.sin(k*tau)
                #temp_list.append(U_xt[k][j])
            else:
                U_xt[k][j]=sigma*(U_xt[k-1][j+1])+(1-2*sigma)*U_xt[k-1][j] + sigma*U_xt[k-1][j-1] +tau*funk_1(j*h,k*tau)
                #temp_list.append(U_xt[k][j])
    
'''        if j==0 or j==4 or j==9 or j==14 or j==19:
            temp_list.append(U_xt[k][j])  '''   

U_x_dop=[[],[],[],[],[]]
#print(len(K))
for j in range(0,N):
    for k in range(K):
        if j==0:
            U_x_dop[0].append((U_xt[k][j+1]-U_xt[k][j])/h)
        elif j==4:
            U_x_dop[1].append((U_xt[k][j]-U_xt[k][j-1])/h)
        elif j==9:
            U_x_dop[2].append((U_xt[k][j]-U_xt[k][j-1])/h)
        elif j==14:
            U_x_dop[3].append((U_xt[k][j]-U_xt[k][j-1])/h)
        elif j==19:
            U_x_dop[4].append((U_xt[k][j]-U_xt[k][j-1])/h)
    
print(len(U_x_dop),np.shape(U_x_dop))

print(math.pi/8)

U_xt=np.array(U_xt).copy() 
#'''

'''2
U_xt=np.zeros((K,N))
for k in range(0,K-1):
    for j in range(1,N-1): 
        U_xt[k+1][j]=sigma*(U_xt[k][j+1])+(1-2*sigma)*U_xt[k][j] + sigma*U_xt[k][j-1] +tau*funk_1((j-1)*h,k*tau)

    U_xt[k+1][0]=math.sin((k+1)*tau)   
    U_xt[k+1][N-1]=U_xt[k+1][N-2] - h*math.sin((k+1)*tau)
        
        
U_xt=np.array(U_xt).copy() 

#'''


'''
U_xt=np.zeros((N,K))
for i in range(N):
    #print(i)
    U_xt[i][0]=0
    
for i in range(K):
    #print(i)
    U_xt[0][i]=math.sin(i*tau)
    
for j in range (1,N-1):
    for k in range(1,K) : 
        U_xt[j][k]=sigma*(U_xt[j+1][k-1])+(1-2*sigma)*U_xt[j][k-1] + sigma*U_xt[j-1][k-1] + tau*funk_1(j*h,k*tau)
        #U_xt[N-1][k]= function 2

for i in range(1,K):
    U_xt[N-1][i]=U_xt[N-2][i] - h*math.sin(i*tau)

U_xt=np.array(U_xt).copy() 
U_xt=U_xt.transpose()
#'''

print(np.shape(U_xt))
# Out:
# 0.07853981633974483
# 0.00125 <= 0.003084251375340424 Well, that`s oke
# 5 (5, 800)
# 0.39269908169872414
# (800, 20)

# %%
def grafik(X,T,h,tau):
    x_x=np.arange(0,X,h)
    y_t=np.arange(0,T,tau)
    #print(len(x_x),len(y_t))
    
    xgrid,ygrid=np.meshgrid(x_x,y_t)#np.meshgrid(y_t,x_x)#
    print(np.shape(xgrid),np.shape(ygrid))
    return xgrid,ygrid#x_x,y_t

x,y=grafik(math.pi/2,T,h,tau)

print(np.shape(x),'x','\n')
print(np.shape(y),'y','\n')
print(np.shape(U_xt))

'''for i in range(len(U_xt)):
    for j in range(len(U_xt[0])):
        U_xt2.append(U_xt[i][j])
        
U_xt2=np.array(U_xt2).copy() 
'''
# Out:
# (800, 20) (800, 20)
# (800, 20) x
#
# (800, 20) y
#
# (800, 20)
# 'for i in range(len(U_xt)):\n    for j in range(len(U_xt[0])):\n        U_xt2.append(U_xt[i][j])\n        \nU_xt2=np.array(U_xt2).copy() \n'

# %%
# %matplotlib notebook
from matplotlib import pylab as plt
from matplotlib import rcParams
import pylab as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

rcParams['figure.dpi']=100
fig=plt.figure(figsize = (6,4))
axes=Axes3D(fig)

axes.set_xlabel('X', fontsize = 12)
axes.set_ylabel('T', fontsize = 12)
axes.set_zlabel('U(x,t)', fontsize = 12)

surf=axes.plot_surface(x,y,U_xt,cmap=cm.Spectral, rstride=1, cstride=1)
#surf=axes.plot_surface(x,y,U_xt,cmap=cm.Wistia, rstride=1, cstride=1)
#surf=axes.plot_surface(x,y,U_xt,cmap=cm.magma, rstride=1, cstride=1)
#axes.view_unit(30,30)
fig.colorbar(surf)
plt.show()

'''plt.plot(x,U_xt[8])
plt.show()'''
# Out:
# <img src="data:image/png;base64,..." width="600">
# 'plt.plot(x,U_xt[8])\nplt.show()'

# %%
import numpy as np
from matplotlib import pylab as plt
from matplotlib import rcParams
# %matplotlib inline

rcParams['figure.dpi']=150
fig,Axes=plt.subplots()

y_dop=np.arange(0,T,tau)

#print(len(y_dop))
print(len(U_x_dop[0]))
plt.plot(y_dop,U_x_dop[0],'--',color='red',label='x=0')
#plt.show()

print(len(U_x_dop[1]))
plt.plot(y_dop,U_x_dop[1],'--',color='g',label='x=pi/8')
#plt.show()

print(len(U_x_dop[2]))
plt.plot(y_dop,U_x_dop[2],'--',color='blue',label='x=pi/4')
#plt.show()

print(len(U_x_dop[3]))
plt.plot(y_dop,U_x_dop[3],'--',color='black',label='x=3pi/8')
#plt.show()

print(len(U_x_dop[4]))
plt.plot(y_dop,U_x_dop[4],'--',color='yellow',label='x=pi/2')

box=[]
for i in range(len(y_dop)):
    box.append(math.sin(-y_dop[i]))
print(len(box))
plt.scatter(y_dop,box,color='yellow',label='x=pi/2')

plt.title('x=0...x=pi/2')

Axes.set_xlabel('T')
Axes.set_ylabel('U_xt')

plt.legend()
plt.grid(True)
plt.show()

uuu=[]
#for j in range(0,N):
for k in range(K):
    uuu.append(U_xt[k][1])
        
#print(len(U_x_dop[0]))
plt.plot(y_dop,uuu,'--',color='red',label='x=0')
plt.grid(True)
plt.show()
# Out:
# 800
# 800
# 800
# 800
# 800
# 800
